# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dense, Flatten
import keras
from keras.preprocessing.image import ImageDataGenerator

from keras.optimizers import SGD
from keras.optimizers import Adam
import matplotlib.pyplot as plt

import os

# %%
from keras.layers import Dropout

# %%
from keras.layers import BatchNormalization

# %%
from keras.layers import LeakyReLU

# %%
from keras.callbacks import EarlyStopping

# %%
model = Sequential()

#less filters
model.add(Conv2D(8, (5,5), padding='same',input_shape=(224,224,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(8, (5,5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

#stacked convolutional layers
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

#smaller Dense layer
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('relu'))

model.add(Dense(2))
model.add(Activation('softmax'))

#overall much less parameters to train, even though deeper
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 8)       608
# _________________________________________________________________
# activation_6 (Activation)    (None, 224, 224, 8)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 112, 112, 8)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 8)       1608
# _________________________________________________________________
# activation_7 (Activation)    (None, 112, 112, 8)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 16)        1168
# _________________________________________________________________
# activation_8 (Activation)    (None, 56, 56, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 56, 56, 16)        2320
# _________________________________________________________________
# activation_9 (Activation)    (None, 56, 56, 16)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                125450
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 22
# _________________________________________________________________
# activation_11 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 131,176
# Trainable params: 131,176
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Different optimizers
# * original model = gradient descent with learning rate of 0.001
# * new optimizer = Adam
#     *  learning rate will change over time

# %%
opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy',
             metrics=['accuracy'])

# %% [markdown]
# # Data Augmentation

# %%
train_dategen = ImageDataGenerator(
rescale=1.0/255.0,
    featurewise_std_normalization=True,
    featurewise_center =True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    brightness_range=[0.2,1.0]
)

# %%
#create data augmentation on training dataset
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import save_img

# %%
import os

# %%
import glob

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create cancer image augmentation

# %%
base_url = 'C:\\Users\\spenc\\Desktop\\CapstonB_Dataset\\OriginalData\\Train\\Cancer'
dir_list = os.listdir(base_url)
dir_list
# Out:
# ['DBT-P00013_rmlo_0.JPEG',
#  'DBT-P00013_rmlo_1.JPEG',
#  'DBT-P00013_rmlo_10.JPEG',
#  'DBT-P00013_rmlo_11.JPEG',
#  'DBT-P00013_rmlo_12.JPEG',
#  'DBT-P00024_lmlo_388.JPEG',
#  'DBT-P00024_lmlo_389.JPEG',
#  'DBT-P00024_lmlo_390.JPEG',
#  'DBT-P00024_lmlo_391.JPEG',
#  'DBT-P00024_lmlo_392.JPEG',
#  'DBT-P00024_lmlo_393.JPEG',
#  'DBT-P00024_lmlo_394.JPEG',
#  'DBT-P00024_lmlo_395.JPEG',
#  'DBT-P00024_lmlo_396.JPEG',
#  'DBT-P00024_lmlo_397.JPEG',
#  'DBT-P00024_lmlo_398.JPEG',
#  'DBT-P00024_lmlo_399.JPEG',
#  'DBT-P00024_lmlo_400.JPEG',
#  'DBT-P00024_lmlo_401.JPEG',
#  'DBT-P00024_lmlo_402.JPEG',
#  'DBT-P00024_lmlo_403.JPEG',
#  'DBT-P00024_lmlo_404.JPEG',
#  'DBT-P00024_lmlo_405.JPEG',
#  'DBT-P00024_lmlo_406.JPEG',
#  'DBT-P00024_lmlo_407.JPEG',
#  'DBT-P00024_lmlo_408.JPEG',
#  'DBT-P00024_lmlo_409.JPEG',
#  'DBT-P00024_lmlo_410.JPEG',
#  'DBT-P00024_lmlo_411.JPEG',
#  'DBT-P00024_lmlo_412.JPEG',
#  'DBT-P00024_lmlo_413.JPEG',
#  'DBT-P00024_lmlo_414.JPEG',
#  'DBT-P00024_lmlo_415.JPEG',
#  'DBT-P00024_lmlo_416.JPEG',
#  'DBT-P00024_lmlo_417.JPEG',
#  'DBT-P00024_lmlo_418.JPEG',
#  'DBT-P00024_lmlo_419.JPEG',
#  'DBT-P00024_lmlo_420.JPEG',
#  'DBT-P00024_lmlo_421.JPEG',
#  'DBT-P00024_lmlo_422.JPEG',
#  'DBT-P00024_lmlo_423.JPEG',
#  'DBT-P00024_lmlo_424.JPEG',
#  'DBT-P00024_lmlo_425.JPEG',
#  'DBT-P00024_lmlo_426.JPEG',
#  'DBT-P00024_lmlo_427.JPEG',
#  'DBT-P00024_lmlo_428.JPEG',
#  'DBT-P00024_lmlo_429.JPEG',
#  'DBT-P00024_lmlo_430.JPEG',
#  'DBT-P00024_lmlo_431.JPEG',
#  'DBT-P00024_lmlo_432.JPEG',
#  'DBT-P00024_lmlo_433.JPEG',
#  'DBT-P00024_lmlo_434.JPEG',
#  'DBT-P00024_lmlo_435.JPEG',
#  'DBT-P00024_lmlo_436.JPEG',
#  'DBT-P00024_lmlo_437.JPEG',
#  'DBT-P00024_lmlo_438.JPEG',
#  'DBT-P00024_lmlo_439.JPEG',
#  'DBT-P00024_lmlo_440.JPEG',
#  'DBT-P00024_lmlo_441.JPEG',
#  'DBT-P00024_lmlo_442.JPEG',
#  'DBT-P00024_lmlo_443.JPEG',
#  'DBT-P00024_lmlo_444.JPEG',
#  'DBT-P00024_lmlo_445.JPEG',
#  'DBT-P00024_lmlo_446.JPEG',
#  'DBT-P00024_lmlo_447.JPEG',
#  'DBT-P00024_lmlo_448.JPEG',
#  'DBT-P00024_lmlo_449.JPEG',
#  'DBT-P00024_lmlo_450.JPEG',
#  'DBT-P00024_lmlo_451.JPEG',
#  'DBT-P00024_lmlo_452.JPEG',
#  'DBT-P00024_lmlo_453.JPEG',
#  'DBT-P00060_rcc_1432.JPEG',
#  'DBT-P00060_rcc_1433.JPEG',
#  'DBT-P00060_rcc_1434.JPEG',
#  'DBT-P00060_rcc_1435.JPEG',
#  'DBT-P00060_rcc_1436.JPEG',
#  'DBT-P00060_rcc_1437.JPEG',
#  'DBT-P00060_rcc_1438.JPEG',
#  'DBT-P00060_rcc_1439.JPEG',
#  'DBT-P00060_rcc_1440.JPEG',
#  'DBT-P00060_rcc_1441.JPEG',
#  'DBT-P00060_rcc_1442.JPEG',
#  'DBT-P00060_rcc_1443.JPEG',
#  'DBT-P00060_rcc_1444.JPEG',
#  'DBT-P00060_rcc_1445.JPEG',
#  'DBT-P00060_rcc_1446.JPEG',
#  'DBT-P00060_rcc_1447.JPEG',
#  'DBT-P00060_rcc_1448.JPEG',
#  'DBT-P00060_rcc_1449.JPEG',
#  'DBT-P00060_rcc_1450.JPEG',
#  'DBT-P00060_rcc_1451.JPEG',
#  'DBT-P00060_rcc_1452.JPEG',
#  'DBT-P00060_rcc_1453.JPEG',
#  'DBT-P00060_rcc_1454.JPEG',
#  'DBT-P00060_rcc_1455.JPEG',
#  'DBT-P00060_rcc_1456.JPEG',
#  'DBT-P00060_rcc_1457.JPEG',
#  'DBT-P00060_rcc_1458.JPEG',
#  'DBT-P00060_rcc_1459.JPEG',
#  'DBT-P00060_rcc_1460.JPEG',
#  'DBT-P00060_rcc_1461.JPEG',
#  'DBT-P00060_rcc_1462.JPEG',
#  'DBT-P00060_rcc_1463.JPEG',
#  'DBT-P00060_rcc_1464.JPEG',
#  'DBT-P00060_rcc_1465.JPEG',
#  'DBT-P00060_rcc_1466.JPEG',
#  'DBT-P00060_rcc_1467.JPEG',
#  'DBT-P00060_rcc_1468.JPEG',
#  'DBT-P00060_rcc_1469.JPEG',
#  'DBT-P00060_rcc_1470.JPEG',
#  'DBT-P00060_rcc_1471.JPEG',
#  'DBT-P00060_rcc_1472.JPEG',
#  'DBT-P00060_rcc_1473.JPEG',
#  'DBT-P00060_rcc_1474.JPEG',
#  'DBT-P00060_rcc_1475.JPEG',
#  'DBT-P00060_rcc_1476.JPEG',
#  'DBT-P00060_rcc_1477.JPEG',
#  'DBT-P00060_rcc_1478.JPEG',
#  'DBT-P00060_rcc_1479.JPEG',
#  'DBT-P00060_rcc_1480.JPEG',
#  'DBT-P00060_rcc_1481.JPEG',
#  'DBT-P00060_rcc_1482.JPEG',
#  'DBT-P00060_rcc_1483.JPEG',
#  'DBT-P00060_rcc_1484.JPEG',
#  'DBT-P00060_rcc_1485.JPEG',
#  'DBT-P00060_rcc_1486.JPEG',
#  'DBT-P00060_rcc_1487.JPEG',
#  'DBT-P00060_rcc_1488.JPEG',
#  'DBT-P00060_rcc_1489.JPEG',
#  'DBT-P00060_rcc_1490.JPEG',
#  'DBT-P00060_rcc_1491.JPEG',
#  'DBT-P00060_rcc_1492.JPEG',
#  'DBT-P00060_rcc_1493.JPEG',
#  'DBT-P00060_rcc_1494.JPEG',
#  'DBT-P00107_lcc_1933.JPEG',
#  'DBT-P00107_lcc_1934.JPEG',
#  'DBT-P00107_lcc_1935.JPEG',
#  'DBT-P00107_lcc_1936.JPEG',
#  'DBT-P00107_lmlo_1937.JPEG',
#  'DBT-P00107_lmlo_1938.JPEG',
#  'DBT-P00107_lmlo_1939.JPEG',
#  'DBT-P00107_lmlo_1940.JPEG',
#  'DBT-P00107_lmlo_1941.JPEG',
#  'DBT-P00107_lmlo_1942.JPEG',
#  'DBT-P00107_lmlo_1943.JPEG',
#  'DBT-P00107_lmlo_1944.JPEG',
#  'DBT-P00107_lmlo_1945.JPEG',
#  'DBT-P00107_lmlo_1946.JPEG',
#  'DBT-P00107_lmlo_1947.JPEG',
#  'DBT-P00107_lmlo_1948.JPEG',
#  'DBT-P00107_lmlo_1949.JPEG',
#  'DBT-P00107_lmlo_1950.JPEG',
#  'DBT-P00107_lmlo_1951.JPEG',
#  'DBT-P00107_lmlo_1952.JPEG',
#  'DBT-P00107_lmlo_1953.JPEG',
#  'DBT-P00107_lmlo_1954.JPEG',
#  'DBT-P00107_lmlo_1955.JPEG',
#  'DBT-P00107_lmlo_1956.JPEG',
#  'DBT-P00107_lmlo_1957.JPEG',
#  'DBT-P00107_lmlo_1958.JPEG',
#  'DBT-P00107_lmlo_1959.JPEG',
#  'DBT-P00107_lmlo_1960.JPEG',
#  'DBT-P00107_lmlo_1961.JPEG',
#  'DBT-P00107_lmlo_1962.JPEG',
#  'DBT-P00107_lmlo_1963.JPEG',
#  'DBT-P00107_lmlo_1964.JPEG',
#  'DBT-P00107_lmlo_1965.JPEG',
#  'DBT-P00107_lmlo_1966.JPEG',
#  'DBT-P00107_lmlo_1967.JPEG',
#  'DBT-P00107_lmlo_1968.JPEG',
#  'DBT-P00107_lmlo_1969.JPEG',
#  'DBT-P00107_lmlo_1970.JPEG',
#  'DBT-P00107_lmlo_1971.JPEG',
#  'DBT-P00107_lmlo_1972.JPEG',
#  'DBT-P00107_lmlo_1973.JPEG',
#  'DBT-P00107_lmlo_1974.JPEG',
#  'DBT-P00107_lmlo_1975.JPEG',
#  'DBT-P00107_lmlo_1976.JPEG',
#  'DBT-P00107_lmlo_1977.JPEG',
#  'DBT-P00107_lmlo_1978.JPEG',
#  'DBT-P00107_lmlo_1979.JPEG',
#  'DBT-P00107_lmlo_1980.JPEG',
#  'DBT-P00107_lmlo_1981.JPEG',
#  'DBT-P00107_lmlo_1982.JPEG',
#  'DBT-P00107_lmlo_1983.JPEG',
#  'DBT-P00107_lmlo_1984.JPEG',
#  'DBT-P00107_lmlo_1985.JPEG',
#  'DBT-P00107_lmlo_1986.JPEG',
#  'DBT-P00107_lmlo_1987.JPEG',
#  'DBT-P00107_lmlo_1988.JPEG',
#  'DBT-P00107_lmlo_1989.JPEG',
#  'DBT-P00107_lmlo_1990.JPEG',
#  'DBT-P00107_lmlo_1991.JPEG',
#  'DBT-P00107_lmlo_1992.JPEG',
#  'DBT-P00107_lmlo_1993.JPEG',
#  'DBT-P00107_lmlo_1994.JPEG',
#  'DBT-P00107_lmlo_1995.JPEG',
#  'DBT-P00107_lmlo_1996.JPEG',
#  'DBT-P00107_lmlo_1997.JPEG',
#  'DBT-P00107_lmlo_1998.JPEG',
#  'DBT-P00107_lmlo_1999.JPEG',
#  'DBT-P00107_lmlo_2000.JPEG',
#  'DBT-P00107_lmlo_2001.JPEG',
#  'DBT-P00107_lmlo_2002.JPEG',
#  'DBT-P00107_lmlo_2003.JPEG',
#  'DBT-P00107_lmlo_2004.JPEG',
#  'DBT-P00107_lmlo_2005.JPEG',
#  'DBT-P00107_lmlo_2006.JPEG',
#  'DBT-P00107_lmlo_2007.JPEG',
#  'DBT-P00107_lmlo_2008.JPEG',
#  'DBT-P00107_lmlo_2009.JPEG',
#  'DBT-P00225_lcc_6978.JPEG',
#  'DBT-P00225_lcc_6979.JPEG',
#  'DBT-P00225_lcc_6980.JPEG',
#  'DBT-P00225_lcc_6981.JPEG',
#  'DBT-P00225_lcc_6982.JPEG',
#  'DBT-P00225_lcc_6983.JPEG',
#  'DBT-P00225_lcc_6984.JPEG',
#  'DBT-P00225_lcc_6985.JPEG',
#  'DBT-P00225_lcc_6986.JPEG',
#  'DBT-P00225_lcc_6987.JPEG',
#  'DBT-P00225_lcc_6988.JPEG',
#  'DBT-P00225_lcc_6989.JPEG',
#  'DBT-P00225_lcc_6990.JPEG',
#  'DBT-P00225_lcc_6991.JPEG',
#  'DBT-P00225_lcc_6992.JPEG',
#  'DBT-P00225_lcc_6993.JPEG',
#  'DBT-P00225_lcc_6994.JPEG',
#  'DBT-P00225_lcc_6995.JPEG',
#  'DBT-P00225_lcc_6996.JPEG',
#  'DBT-P00225_lcc_6997.JPEG',
#  'DBT-P00225_lcc_6998.JPEG',
#  'DBT-P00225_lcc_6999.JPEG',
#  'DBT-P00225_lcc_7000.JPEG',
#  'DBT-P00225_lcc_7001.JPEG',
#  'DBT-P00225_lcc_7002.JPEG',
#  'DBT-P00225_lcc_7003.JPEG',
#  'DBT-P00225_lcc_7004.JPEG',
#  'DBT-P00225_lcc_7005.JPEG',
#  'DBT-P00225_lcc_7006.JPEG',
#  'DBT-P00225_lcc_7007.JPEG',
#  'DBT-P00225_lcc_7008.JPEG',
#  'DBT-P00225_lcc_7009.JPEG',
#  'DBT-P00225_lcc_7010.JPEG',
#  'DBT-P00225_lcc_7011.JPEG',
#  'DBT-P00225_lcc_7012.JPEG',
#  'DBT-P00225_lcc_7013.JPEG',
#  'DBT-P00225_lcc_7014.JPEG',
#  'DBT-P00225_lcc_7015.JPEG',
#  'DBT-P00225_lcc_7016.JPEG',
#  'DBT-P00225_lcc_7017.JPEG',
#  'DBT-P00225_lcc_7018.JPEG',
#  'DBT-P00225_lcc_7019.JPEG',
#  'DBT-P00225_lcc_7020.JPEG',
#  'DBT-P00225_lcc_7021.JPEG',
#  'DBT-P00225_lcc_7022.JPEG',
#  'DBT-P00225_lcc_7023.JPEG',
#  'DBT-P00225_lcc_7024.JPEG',
#  'DBT-P00225_lcc_7025.JPEG',
#  'DBT-P00225_lcc_7026.JPEG',
#  'DBT-P00225_lmlo_7069.JPEG',
#  'DBT-P00225_lmlo_7070.JPEG',
#  'DBT-P00225_lmlo_7071.JPEG',
#  'DBT-P00225_lmlo_7072.JPEG',
#  'DBT-P00225_lmlo_7073.JPEG',
#  'DBT-P00225_lmlo_7074.JPEG',
#  'DBT-P00225_lmlo_7075.JPEG',
#  'DBT-P00225_lmlo_7076.JPEG',
#  'DBT-P00225_lmlo_7077.JPEG',
#  'DBT-P00225_lmlo_7078.JPEG',
#  'DBT-P00225_lmlo_7079.JPEG',
#  'DBT-P00225_lmlo_7080.JPEG',
#  'DBT-P00225_lmlo_7081.JPEG',
#  'DBT-P00225_lmlo_7082.JPEG',
#  'DBT-P00225_lmlo_7083.JPEG',
#  'DBT-P00225_lmlo_7084.JPEG',
#  'DBT-P00225_lmlo_7085.JPEG',
#  'DBT-P00225_lmlo_7086.JPEG',
#  'DBT-P00225_lmlo_7087.JPEG',
#  'DBT-P00225_lmlo_7088.JPEG',
#  'DBT-P00225_lmlo_7089.JPEG',
#  'DBT-P00225_lmlo_7090.JPEG',
#  'DBT-P00225_lmlo_7091.JPEG',
#  'DBT-P00225_lmlo_7092.JPEG',
#  'DBT-P00225_lmlo_7093.JPEG',
#  'DBT-P00225_lmlo_7094.JPEG',
#  'DBT-P00225_lmlo_7095.JPEG',
#  'DBT-P00225_lmlo_7096.JPEG',
#  'DBT-P00225_lmlo_7097.JPEG',
#  'DBT-P00225_lmlo_7098.JPEG',
#  'DBT-P00225_lmlo_7099.JPEG',
#  'DBT-P00225_lmlo_7100.JPEG',
#  'DBT-P00225_lmlo_7101.JPEG',
#  'DBT-P00225_lmlo_7102.JPEG',
#  'DBT-P00225_lmlo_7103.JPEG',
#  'DBT-P00225_lmlo_7104.JPEG',
#  'DBT-P00225_lmlo_7105.JPEG',
#  'DBT-P00225_lmlo_7106.JPEG',
#  'DBT-P00225_lmlo_7107.JPEG',
#  'DBT-P00225_lmlo_7108.JPEG',
#  'DBT-P00225_lmlo_7109.JPEG',
#  'DBT-P00225_lmlo_7110.JPEG',
#  'DBT-P00225_lmlo_7111.JPEG',
#  'DBT-P00225_lmlo_7112.JPEG',
#  'DBT-P00225_lmlo_7113.JPEG',
#  'DBT-P00225_lmlo_7114.JPEG',
#  'DBT-P00225_lmlo_7115.JPEG',
#  'DBT-P00225_lmlo_7116.JPEG',
#  'DBT-P00225_lmlo_7117.JPEG',
#  'DBT-P00225_lmlo_7118.JPEG',
#  'DBT-P00225_lmlo_7119.JPEG',
#  'DBT-P00225_lmlo_7120.JPEG',
#  'DBT-P00225_lmlo_7121.JPEG',
#  'DBT-P00225_lmlo_7122.JPEG',
#  'DBT-P00225_lmlo_7123.JPEG',
#  'DBT-P00225_lmlo_7124.JPEG',
#  'DBT-P00225_lmlo_7125.JPEG',
#  'DBT-P00225_lmlo_7126.JPEG',
#  'DBT-P00225_lmlo_7127.JPEG',
#  'DBT-P00225_lmlo_7128.JPEG',
#  'DBT-P00225_lmlo_7129.JPEG',
#  'DBT-P00225_lmlo_7130.JPEG',
#  'DBT-P00225_lmlo_7131.JPEG',
#  'DBT-P00225_lmlo_7132.JPEG',
#  'DBT-P00225_lmlo_7133.JPEG',
#  'DBT-P00225_lmlo_7134.JPEG',
#  'DBT-P00225_lmlo_7135.JPEG',
#  'DBT-P00225_lmlo_7136.JPEG',
#  'DBT-P00225_lmlo_7137.JPEG',
#  'DBT-P00225_lmlo_7138.JPEG',
#  'DBT-P00225_lmlo_7139.JPEG',
#  'DBT-P00225_lmlo_7140.JPEG',
#  'DBT-P00225_lmlo_7141.JPEG',
#  'DBT-P00225_lmlo_7142.JPEG',
#  'DBT-P00225_lmlo_7143.JPEG',
#  'DBT-P00225_lmlo_7144.JPEG',
#  'DBT-P00225_lmlo_7145.JPEG',
#  'DBT-P00225_lmlo_7146.JPEG',
#  'DBT-P00225_lmlo_7147.JPEG',
#  'DBT-P00225_lmlo_7148.JPEG',
#  'DBT-P00225_lmlo_7149.JPEG',
#  'DBT-P00225_lmlo_7150.JPEG',
#  'DBT-P00225_lmlo_7151.JPEG',
#  'DBT-P00225_lmlo_7152.JPEG',
#  'DBT-P00225_lmlo_7153.JPEG',
#  'DBT-P00225_lmlo_7154.JPEG',
#  'DBT-P00225_lmlo_7155.JPEG',
#  'DBT-P00225_lmlo_7156.JPEG',
#  'DBT-P00225_lmlo_7157.JPEG',
#  'DBT-P00225_lmlo_7158.JPEG',
#  'DBT-P00225_lmlo_7785.JPEG',
#  'DBT-P00225_lmlo_7786.JPEG',
#  'DBT-P00225_lmlo_7787.JPEG',
#  'DBT-P00225_lmlo_7788.JPEG',
#  'DBT-P00225_lmlo_7789.JPEG',
#  'DBT-P00225_lmlo_7790.JPEG',
#  'DBT-P00225_lmlo_7791.JPEG',
#  'DBT-P00225_lmlo_7792.JPEG',
#  'DBT-P00225_lmlo_7793.JPEG',
#  'DBT-P00225_lmlo_7794.JPEG',
#  'DBT-P00225_lmlo_7795.JPEG',
#  'DBT-P00225_lmlo_7796.JPEG',
#  'DBT-P00225_lmlo_7797.JPEG',
#  'DBT-P00225_lmlo_7798.JPEG',
#  'DBT-P00225_lmlo_7799.JPEG',
#  'DBT-P00225_lmlo_7800.JPEG',
#  'DBT-P00225_lmlo_7801.JPEG',
#  'DBT-P00225_lmlo_7802.JPEG',
#  'DBT-P00225_lmlo_7803.JPEG',
#  'DBT-P00225_lmlo_7804.JPEG',
#  'DBT-P00225_lmlo_7805.JPEG',
#  'DBT-P00225_lmlo_7806.JPEG',
#  'DBT-P00225_lmlo_7807.JPEG',
#  'DBT-P00225_lmlo_7808.JPEG',
#  'DBT-P00225_lmlo_7809.JPEG',
#  'DBT-P00225_lmlo_7810.JPEG',
#  'DBT-P00225_lmlo_7811.JPEG',
#  'DBT-P00225_lmlo_7812.JPEG',
#  'DBT-P00225_lmlo_7813.JPEG',
#  'DBT-P00225_lmlo_7814.JPEG',
#  'DBT-P00225_lmlo_7815.JPEG',
#  'DBT-P00225_lmlo_7816.JPEG',
#  'DBT-P00225_lmlo_7817.JPEG',
#  'DBT-P00225_lmlo_7818.JPEG',
#  'DBT-P00225_lmlo_7819.JPEG',
#  'DBT-P00225_lmlo_7820.JPEG',
#  'DBT-P00225_lmlo_7821.JPEG',
#  'DBT-P00225_lmlo_7822.JPEG',
#  'DBT-P00225_lmlo_7823.JPEG',
#  'DBT-P00225_lmlo_7824.JPEG',
#  'DBT-P00225_lmlo_7825.JPEG',
#  'DBT-P00225_lmlo_7826.JPEG',
#  'DBT-P00225_lmlo_7827.JPEG',
#  'DBT-P00225_lmlo_7828.JPEG',
#  'DBT-P00225_lmlo_7829.JPEG',
#  'DBT-P00225_lmlo_7830.JPEG',
#  'DBT-P00225_lmlo_7831.JPEG',
#  'DBT-P00225_lmlo_7832.JPEG',
#  'DBT-P00225_lmlo_7833.JPEG',
#  'DBT-P00225_lmlo_7834.JPEG',
#  'DBT-P00225_lmlo_7835.JPEG',
#  'DBT-P00225_lmlo_7836.JPEG',
#  'DBT-P00225_lmlo_7837.JPEG',
#  'DBT-P00225_lmlo_7838.JPEG',
#  'DBT-P00225_lmlo_7839.JPEG',
#  'DBT-P00225_lmlo_7840.JPEG',
#  'DBT-P00225_lmlo_7841.JPEG',
#  'DBT-P00225_lmlo_7842.JPEG',
#  'DBT-P00225_lmlo_7843.JPEG',
#  'DBT-P00225_lmlo_7844.JPEG',
#  'DBT-P00225_lmlo_7845.JPEG',
#  'DBT-P00225_lmlo_7846.JPEG',
#  'DBT-P00225_lmlo_7847.JPEG',
#  'DBT-P00225_lmlo_7848.JPEG',
#  'DBT-P00225_lmlo_7849.JPEG',
#  'DBT-P00225_lmlo_7850.JPEG',
#  'DBT-P00225_lmlo_7851.JPEG',
#  'DBT-P00225_lmlo_7852.JPEG',
#  'DBT-P00225_lmlo_7853.JPEG',
#  'DBT-P00225_lmlo_7854.JPEG',
#  'DBT-P00225_lmlo_7855.JPEG',
#  'DBT-P00225_lmlo_7856.JPEG',
#  'DBT-P00225_lmlo_7857.JPEG',
#  'DBT-P00225_lmlo_7858.JPEG',
#  'DBT-P00225_lmlo_7859.JPEG',
#  'DBT-P00225_lmlo_7860.JPEG',
#  'DBT-P00225_lmlo_7861.JPEG',
#  'DBT-P00225_lmlo_7862.JPEG',
#  'DBT-P00225_lmlo_7863.JPEG',
#  'DBT-P00225_lmlo_7864.JPEG',
#  'DBT-P00225_lmlo_7865.JPEG',
#  'DBT-P00225_lmlo_7866.JPEG',
#  'DBT-P00225_lmlo_7867.JPEG',
#  'DBT-P00225_lmlo_7868.JPEG',
#  'DBT-P00225_lmlo_7869.JPEG',
#  'DBT-P00225_lmlo_7870.JPEG',
#  'DBT-P00225_lmlo_7871.JPEG',
#  'DBT-P00225_lmlo_7872.JPEG',
#  'DBT-P00225_lmlo_7873.JPEG',
#  'DBT-P00225_lmlo_7874.JPEG',
#  'DBT-P00225_lmlo_7875.JPEG',
#  'DBT-P00225_lmlo_7876.JPEG',
#  'DBT-P00225_lmlo_7877.JPEG',
#  'DBT-P00225_lmlo_7878.JPEG',
#  'DBT-P00225_lmlo_7879.JPEG',
#  'DBT-P00303_rcc_8422.JPEG',
#  'DBT-P00303_rcc_8423.JPEG',
#  'DBT-P00303_rcc_8424.JPEG',
#  'DBT-P00303_rcc_8425.JPEG',
#  'DBT-P00303_rcc_8426.JPEG',
#  'DBT-P00303_rcc_8427.JPEG',
#  'DBT-P00303_rcc_8428.JPEG',
#  'DBT-P00303_rcc_8429.JPEG',
#  'DBT-P00303_rcc_8430.JPEG',
#  'DBT-P00303_rcc_8431.JPEG',
#  'DBT-P00303_rcc_8432.JPEG',
#  'DBT-P00303_rcc_8433.JPEG',
#  'DBT-P00303_rcc_8434.JPEG',
#  'DBT-P00303_rcc_8435.JPEG',
#  'DBT-P00303_rcc_8436.JPEG',
#  'DBT-P00303_rcc_8437.JPEG',
#  'DBT-P00303_rcc_8438.JPEG',
#  'DBT-P00303_rcc_8439.JPEG',
#  'DBT-P00303_rcc_8440.JPEG',
#  'DBT-P00303_rcc_8441.JPEG',
#  'DBT-P00303_rcc_8442.JPEG',
#  'DBT-P00303_rcc_8443.JPEG',
#  'DBT-P00303_rcc_8444.JPEG',
#  'DBT-P00303_rcc_8445.JPEG',
#  'DBT-P00303_rcc_8446.JPEG',
#  'DBT-P00303_rcc_8447.JPEG',
#  'DBT-P00303_rcc_8448.JPEG',
#  'DBT-P00303_rcc_8449.JPEG',
#  'DBT-P00303_rcc_8450.JPEG',
#  'DBT-P00303_rcc_8451.JPEG',
#  'DBT-P00303_rcc_8452.JPEG',
#  'DBT-P00303_rcc_8453.JPEG',
#  'DBT-P00303_rcc_8454.JPEG',
#  'DBT-P00303_rcc_8455.JPEG',
#  'DBT-P00303_rcc_8456.JPEG',
#  'DBT-P00303_rcc_8457.JPEG',
#  'DBT-P00303_rcc_8458.JPEG',
#  'DBT-P00303_rcc_8459.JPEG',
#  'DBT-P00303_rcc_8460.JPEG',
#  'DBT-P00303_rcc_8461.JPEG',
#  'DBT-P00303_rcc_8462.JPEG',
#  'DBT-P00303_rcc_8463.JPEG',
#  'DBT-P00303_rcc_8464.JPEG',
#  'DBT-P00303_rcc_8465.JPEG',
#  'DBT-P00303_rcc_8466.JPEG',
#  'DBT-P00303_rcc_8467.JPEG',
#  'DBT-P00303_rcc_8468.JPEG',
#  'DBT-P00303_rcc_8469.JPEG',
#  'DBT-P00303_rcc_8470.JPEG',
#  'DBT-P00303_rcc_8471.JPEG',
#  'DBT-P00303_rcc_8472.JPEG',
#  'DBT-P00303_rcc_8473.JPEG',
#  'DBT-P00303_rcc_8474.JPEG',
#  'DBT-P00303_rcc_8475.JPEG',
#  'DBT-P00303_rcc_8476.JPEG',
#  'DBT-P00303_rcc_8477.JPEG',
#  'DBT-P00303_rcc_8478.JPEG',
#  'DBT-P00303_rcc_8479.JPEG',
#  'DBT-P00303_rcc_8480.JPEG',
#  'DBT-P00303_rcc_9722.JPEG',
#  'DBT-P00303_rcc_9723.JPEG',
#  'DBT-P00303_rcc_9724.JPEG',
#  'DBT-P00303_rcc_9725.JPEG',
#  'DBT-P00303_rcc_9726.JPEG',
#  'DBT-P00303_rcc_9727.JPEG',
#  'DBT-P00303_rcc_9728.JPEG',
#  'DBT-P00303_rcc_9729.JPEG',
#  'DBT-P00303_rcc_9730.JPEG',
#  'DBT-P00303_rcc_9731.JPEG',
#  'DBT-P00303_rcc_9732.JPEG',
#  'DBT-P00303_rcc_9733.JPEG',
#  'DBT-P00303_rcc_9734.JPEG',
#  'DBT-P00303_rcc_9735.JPEG',
#  'DBT-P00303_rcc_9736.JPEG',
#  'DBT-P00303_rcc_9737.JPEG',
#  'DBT-P00303_rcc_9738.JPEG',
#  'DBT-P00303_rcc_9739.JPEG',
#  'DBT-P00303_rcc_9740.JPEG',
#  'DBT-P00303_rcc_9741.JPEG',
#  'DBT-P00303_rcc_9742.JPEG',
#  'DBT-P00303_rcc_9743.JPEG',
#  'DBT-P00303_rcc_9744.JPEG',
#  'DBT-P00303_rcc_9745.JPEG',
#  'DBT-P00303_rcc_9746.JPEG',
#  'DBT-P00303_rcc_9747.JPEG',
#  'DBT-P00303_rcc_9748.JPEG',
#  'DBT-P00303_rcc_9749.JPEG',
#  'DBT-P00303_rcc_9750.JPEG',
#  'DBT-P00303_rcc_9751.JPEG',
#  'DBT-P00303_rcc_9752.JPEG',
#  'DBT-P00303_rcc_9753.JPEG',
#  'DBT-P00303_rcc_9754.JPEG',
#  'DBT-P00303_rcc_9755.JPEG',
#  'DBT-P00303_rcc_9756.JPEG',
#  'DBT-P00303_rcc_9757.JPEG',
#  'DBT-P00303_rcc_9758.JPEG',
#  'DBT-P00303_rcc_9759.JPEG',
#  'DBT-P00303_rcc_9760.JPEG',
#  'DBT-P00303_rcc_9761.JPEG',
#  'DBT-P00303_rcc_9762.JPEG',
#  'DBT-P00303_rcc_9763.JPEG',
#  'DBT-P00303_rcc_9764.JPEG',
#  'DBT-P00303_rcc_9765.JPEG',
#  'DBT-P00303_rcc_9766.JPEG',
#  'DBT-P00303_rcc_9767.JPEG',
#  'DBT-P00303_rcc_9768.JPEG',
#  'DBT-P00303_rcc_9769.JPEG',
#  'DBT-P00303_rcc_9770.JPEG',
#  'DBT-P00303_rcc_9771.JPEG',
#  'DBT-P00303_rcc_9772.JPEG',
#  'DBT-P00303_rcc_9773.JPEG',
#  'DBT-P00303_rcc_9774.JPEG',
#  'DBT-P00303_rcc_9775.JPEG',
#  'DBT-P00303_rcc_9776.JPEG',
#  'DBT-P00303_rcc_9777.JPEG',
#  'DBT-P00303_rcc_9778.JPEG',
#  'DBT-P00303_rcc_9779.JPEG',
#  'DBT-P00303_rcc_9780.JPEG',
#  'DBT-P00303_rmlo_8481.JPEG',
#  'DBT-P00303_rmlo_8482.JPEG',
#  'DBT-P00303_rmlo_8483.JPEG',
#  'DBT-P00303_rmlo_8484.JPEG',
#  'DBT-P00303_rmlo_8485.JPEG',
#  'DBT-P00303_rmlo_8486.JPEG',
#  'DBT-P00303_rmlo_8487.JPEG',
#  'DBT-P00303_rmlo_8488.JPEG',
#  'DBT-P00303_rmlo_8489.JPEG',
#  'DBT-P00303_rmlo_8490.JPEG',
#  'DBT-P00303_rmlo_8491.JPEG',
#  'DBT-P00303_rmlo_9794.JPEG',
#  'DBT-P00303_rmlo_9795.JPEG',
#  'DBT-P00303_rmlo_9796.JPEG',
#  'DBT-P00303_rmlo_9797.JPEG',
#  'DBT-P00303_rmlo_9798.JPEG',
#  'DBT-P00303_rmlo_9799.JPEG',
#  'DBT-P00303_rmlo_9800.JPEG',
#  'DBT-P00303_rmlo_9801.JPEG',
#  'DBT-P00303_rmlo_9802.JPEG',
#  'DBT-P00303_rmlo_9803.JPEG',
#  'DBT-P00303_rmlo_9804.JPEG',
#  'DBT-P00303_rmlo_9805.JPEG',
#  'DBT-P00303_rmlo_9806.JPEG',
#  'DBT-P00303_rmlo_9807.JPEG',
#  'DBT-P00303_rmlo_9808.JPEG',
#  'DBT-P00303_rmlo_9809.JPEG',
#  'DBT-P00303_rmlo_9810.JPEG',
#  'DBT-P00303_rmlo_9811.JPEG',
#  'DBT-P00303_rmlo_9812.JPEG',
#  'DBT-P00303_rmlo_9813.JPEG',
#  'DBT-P00303_rmlo_9814.JPEG',
#  'DBT-P00303_rmlo_9815.JPEG',
#  'DBT-P00303_rmlo_9816.JPEG',
#  'DBT-P00303_rmlo_9817.JPEG',
#  'DBT-P00303_rmlo_9818.JPEG',
#  'DBT-P00303_rmlo_9819.JPEG',
#  'DBT-P00303_rmlo_9820.JPEG',
#  'DBT-P00303_rmlo_9821.JPEG',
#  'DBT-P00303_rmlo_9822.JPEG',
#  'DBT-P00303_rmlo_9823.JPEG',
#  'DBT-P00303_rmlo_9824.JPEG',
#  'DBT-P00303_rmlo_9825.JPEG',
#  'DBT-P00303_rmlo_9826.JPEG',
#  'DBT-P00303_rmlo_9827.JPEG',
#  'DBT-P00303_rmlo_9828.JPEG',
#  'DBT-P00303_rmlo_9829.JPEG',
#  'DBT-P00303_rmlo_9830.JPEG',
#  'DBT-P00303_rmlo_9831.JPEG',
#  'DBT-P00303_rmlo_9832.JPEG',
#  'DBT-P00303_rmlo_9833.JPEG',
#  ...]

# %%
train_cancer_pats = list(set([x.split('_')[0] for x in dir_list]))
train_cancer_pats[:5]
# Out:
# ['DBT-P03292', 'DBT-P03017', 'DBT-P04116', 'DBT-P03658', 'DBT-P00107']

# %%
base_url2 = 'C:\\Users\\spenc\\Desktop\\CapstoneA_Dataset\\JPEG_Images'

# %%
new_base_dir = 'C:\\Users\\spenc\\Desktop\\CapstonB_Dataset\\DataAug\\Cancer'
for x in train_cancer_pats:
    
    #load in 15th image
    img_url = glob.glob(f"{base_url2}\\{x}\\*\\*\\*")[15]
    img = load_img(img_url)
    data = img_to_array(img)
    
    #image augmentation
    samples = expand_dims(data,0)
    datagen = ImageDataGenerator(horizontal_flip=True,rotation_range=10,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                zoom_range=0.2
                                )
    it = datagen.flow(samples, batch_size=1)
    
    #create 3 augmented images per patient
    for i in range(3):
        batch = it.next()
        image = batch[0].astype('uint8')
        new_dir = f"{new_base_dir}\\{x}_{i}.JPEG"
        save_img(new_dir, image)
        #plt.imshow(image)
        #plt.show()

# %% [markdown]
# # Create Normal Image Augmentation

# %%
base_url = 'C:\\Users\\spenc\\Desktop\\CapstonB_Dataset\\OriginalData\\Train\\Normal'
base_url2 = 'C:\\Users\\spenc\\Desktop\\CapstoneA_Dataset\\JPEG_Images'
dir_list = os.listdir(base_url)
train_normal_pats = list(set([x.split('_')[0] for x in dir_list]))
train_normal_pats[:5]
# Out:
# ['DBT-P03718', 'DBT-P00465', 'DBT-P01701', 'DBT-P01660', 'DBT-P04997']

# %%
new_base_dir = 'C:\\Users\\spenc\\Desktop\\CapstonB_Dataset\\DataAug\\Normal'
for x in train_normal_pats:
    
    #load in 15th image
    
    img_url = glob.glob(f"{base_url2}\\{x}\\*\\*\\*")[15]
    
    img = load_img(img_url)
    data = img_to_array(img)
    
    #image augmentation
    samples = expand_dims(data,0)
    datagen = ImageDataGenerator(horizontal_flip=True,rotation_range=10,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                zoom_range=0.2
                                )
    it = datagen.flow(samples, batch_size=1)
    
    #create 1 augmented image per patient
    for i in range(1):
        batch = it.next()
        image = batch[0].astype('uint8')
        new_dir = f"{new_base_dir}\\{x}_{i}.JPEG"
        save_img(new_dir, image)
        #plt.imshow(image)
        #plt.show()

# %% [markdown]
# # Dropout
# * model weights and biases in certain nodes not updated
# * dropout of 0.2 -> each node has 20% probability of being inactived

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), padding='same', input_shape=(224,224,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

# %%
model.add(Flatten())
model.add(Dense(1000))
model.add(Activation('relu'))

model.add(Dense(2))
model.add(Activation('softmax'))
model.add(Dropout(0.2))

model.summary()

# %% [markdown]
# # Batch Normalization
# * original data normalized to zero mean and standard deviation of 1
# * also want to normalize output from an activation function
#     * add batch normalization layer after activation layer

# %%
model = Sequential()

#less filters
model.add(Conv2D(8, (5,5), padding='same',input_shape=(224,224,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(8, (5,5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

#stacked convolutional layers
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

#smaller Dense layer
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('relu'))

model.add(Dense(2))
model.add(Activation('softmax'))

#overall much less parameters to train, even though deeper
model.summary()

# %% [markdown]
# # leaky ReLU Activation
# * scale down negative output by alpha instead of just making it 0 (like in ReLU)

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(LeakyReLU(alpha=0.1))

model.add(Dense(2))
model.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5)
history = model.fit(train_it, ...., callbacks=[es])
